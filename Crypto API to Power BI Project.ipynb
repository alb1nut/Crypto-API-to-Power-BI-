# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd # For Data Transformation
import requests # to establish connection with the web

# %% [markdown]
# ## Extracting data from API

# %%
url ='https://api.coincap.io/v2/assets'

# %%
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
# Json file
responsedata = response.json()
responsedata
# Out:
# {'data': [{'id': 'bitcoin',
#    'rank': '1',
#    'symbol': 'BTC',
#    'name': 'Bitcoin',
#    'supply': '19658368.0000000000000000',
#    'maxSupply': '21000000.0000000000000000',
#    'marketCapUsd': '1355165909044.6780711946191232',
#    'volumeUsd24Hr': '12006398229.6472977917543412',
#    'priceUsd': '68935.8297211995457199',
#    'changePercent24Hr': '-1.2559745009359602',
#    'vwap24Hr': '69867.2512524566142959',
#    'explorer': 'https://blockchain.info/'},
#   {'id': 'ethereum',
#    'rank': '2',
#    'symbol': 'ETH',
#    'name': 'Ethereum',
#    'supply': '120077426.1898597300000000',
#    'maxSupply': None,
#    'marketCapUsd': '421345628047.0649051305278377',
#    'volumeUsd24Hr': '6982423467.7926447631014626',
#    'priceUsd': '3508.9495287886725271',
#    'changePercent24Hr': '-1.8886614233219535',
#    'vwap24Hr': '3564.9111712248007983',
#    'explorer': 'https://etherscan.io/'},
#   {'id': 'tether',
#    'rank': '3',
#    'symbol': 'USDT',
#    'name': 'Tether',
#    'supply': '103618183617.7160800000000000',
#    'maxSupply': None,
#    'marketCapUsd': '103601221120.5180664422074242',
#    'volumeUsd24Hr': '28072783650.2279472476164235',
#    'priceUsd': '0.9998362980646274',
#    'changePercent24Hr': '-0.0492353998425023',
#    'vwap24Hr': '0.9999288321105012',
#    'explorer': 'https://www.omniexplorer.info/asset/31'},
#   {'id': 'binance-coin',
#    'rank': '4',
#    'symbol': 'BNB',
#    'name': 'BNB',
#    'supply': '166801148.0000000000000000',
#    'maxSupply': '166801148.0000000000000000',
#    'marketCapUsd': '95086174456.6936736366821232',
#    'volumeUsd24Hr': '477060035.9600063698535309',
#    'priceUsd': '570.0570745274107684',
#    'changePercent24Hr': '-1.3700083734304190',
#    'vwap24Hr': '575.8235705316241787',
#    'explorer': 'https://etherscan.io/token/0xB8c77482e45F1F44dE1745F52C74426C631bDD52'},
#   {'id': 'solana',
#    'rank': '5',
#    'symbol': 'SOL',
#    'name': 'Solana',
#    'supply': '443884942.2473194000000000',
#    'maxSupply': None,
#    'marketCapUsd': '81882191088.5053842368055237',
#    'volumeUsd24Hr': '1416695336.7724362183967011',
#    'priceUsd': '184.4671519469634969',
#    'changePercent24Hr': '-2.3235182242782317',
#    'vwap24Hr': '186.7407969824341138',
#    'explorer': 'https://explorer.solana.com/'},
#   {'id': 'usd-coin',
#    'rank': '6',
#    'symbol': 'USDC',
#    'name': 'USDC',
#    'supply': '31402000743.4583700000000000',
#    'maxSupply': None,
#    'marketCapUsd': '31423399844.5840501538908726',
#    'volumeUsd24Hr': '2179933329.6200436281785930',
#    'priceUsd': '1.0006814566148349',
#    'changePercent24Hr': '0.0240707405254367',
#    'vwap24Hr': '1.0000538568741173',
#    'explorer': 'https://etherscan.io/token/0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48'},
#   {'id': 'xrp',
#    'rank': '7',
#    'symbol': 'XRP',
#    'name': 'XRP',
#    'supply': '45404028640.0000000000000000',
#    'maxSupply': '100000000000.0000000000000000',
#    'marketCapUsd': '27859721492.1098480517983200',
#    'volumeUsd24Hr': '710855049.6082132321703531',
#    'priceUsd': '0.6135958047468505',
#    'changePercent24Hr': '-2.9007647038394145',
#    'vwap24Hr': '0.6236040485791139',
#    'explorer': 'https://xrpcharts.ripple.com/#/graph/'},
#   {'id': 'dogecoin',
#    'rank': '8',
#    'symbol': 'DOGE',
#    'name': 'Dogecoin',
#    'supply': '143530066383.7052000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '26803835551.0127320457059611',
#    'volumeUsd24Hr': '1681889912.6056277195686474',
#    'priceUsd': '0.1867471828470898',
#    'changePercent24Hr': '4.9699493928370628',
#    'vwap24Hr': '0.1848392814909296',
#    'explorer': 'http://dogechain.info/chain/Dogecoin'},
#   {'id': 'cardano',
#    'rank': '9',
#    'symbol': 'ADA',
#    'name': 'Cardano',
#    'supply': '35565639551.8750000000000000',
#    'maxSupply': '45000000000.0000000000000000',
#    'marketCapUsd': '23039869959.3320999402437780',
#    'volumeUsd24Hr': '293100376.8682845269262418',
#    'priceUsd': '0.6478126149180256',
#    'changePercent24Hr': '-2.0488857567747121',
#    'vwap24Hr': '0.6523196815101588',
#    'explorer': 'https://cardanoexplorer.com/'},
#   {'id': 'avalanche',
#    'rank': '10',
#    'symbol': 'AVAX',
#    'name': 'Avalanche',
#    'supply': '377311201.7659915000000000',
#    'maxSupply': '720000000.0000000000000000',
#    'marketCapUsd': '20395781470.5020964956080542',
#    'volumeUsd24Hr': '378220638.0729589768932302',
#    'priceUsd': '54.0555948910087360',
#    'changePercent24Hr': '-2.9333250331067961',
#    'vwap24Hr': '54.9256480141860129',
#    'explorer': 'https://avascan.info/'},
#   {'id': 'shiba-inu',
#    'rank': '11',
#    'symbol': 'SHIB',
#    'name': 'Shiba Inu',
#    'supply': '589289410812691.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '17768232380.3527387030968671',
#    'volumeUsd24Hr': '772416855.0975664295961383',
#    'priceUsd': '0.0000301519627781',
#    'changePercent24Hr': '-0.5633351693869650',
#    'vwap24Hr': '0.0000305813141753',
#    'explorer': 'https://etherscan.io/token/0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce'},
#   {'id': 'polkadot',
#    'rank': '12',
#    'symbol': 'DOT',
#    'name': 'Polkadot',
#    'supply': '1345861133.6056400000000000',
#    'maxSupply': None,
#    'marketCapUsd': '12696626913.9294150680278506',
#    'volumeUsd24Hr': '167769620.5815764613654226',
#    'priceUsd': '9.4338313195169070',
#    'changePercent24Hr': '-1.9622489988458731',
#    'vwap24Hr': '9.5788195901978903',
#    'explorer': 'https://polkascan.io/polkadot'},
#   {'id': 'chainlink',
#    'rank': '13',
#    'symbol': 'LINK',
#    'name': 'Chainlink',
#    'supply': '587099970.4527867000000000',
#    'maxSupply': '1000000000.0000000000000000',
#    'marketCapUsd': '11354215777.9458383203041563',
#    'volumeUsd24Hr': '254547802.7853629639441642',
#    'priceUsd': '19.3394930154555673',
#    'changePercent24Hr': '-2.5006048693517297',
#    'vwap24Hr': '19.6078462389369211',
#    'explorer': 'https://etherscan.io/token/0x514910771af9ca656af840dff83e8264ecf986ca'},
#   {'id': 'wrapped-bitcoin',
#    'rank': '14',
#    'symbol': 'WBTC',
#    'name': 'Wrapped Bitcoin',
#    'supply': '155584.7087716400000000',
#    'maxSupply': None,
#    'marketCapUsd': '10736228665.6064350492969469',
#    'volumeUsd24Hr': '176021072.8406258226683582',
#    'priceUsd': '69005.6802520649519077',
#    'changePercent24Hr': '-1.1281928208892967',
#    'vwap24Hr': '70064.9373795812429437',
#    'explorer': 'https://etherscan.io/token/0x2260fac5e5542a773aa44fbcfedf7c193bc2c599'},
#   {'id': 'bitcoin-cash',
#    'rank': '15',
#    'symbol': 'BCH',
#    'name': 'Bitcoin Cash',
#    'supply': '19672493.7500000000000000',
#    'maxSupply': '21000000.0000000000000000',
#    'marketCapUsd': '10656484865.0119624120940675',
#    'volumeUsd24Hr': '670818183.4760201335206417',
#    'priceUsd': '541.6946626307588692',
#    'changePercent24Hr': '14.0407982624084032',
#    'vwap24Hr': '508.7187097309265657',
#    'explorer': 'https://blockchair.com/bitcoin-cash/blocks'},
#   {'id': 'tron',
#    'rank': '16',
#    'symbol': 'TRX',
#    'name': 'TRON',
#    'supply': '87827583692.0204600000000000',
#    'maxSupply': None,
#    'marketCapUsd': '10486550780.1378258059108624',
#    'volumeUsd24Hr': '148697663.0697107697855836',
#    'priceUsd': '0.1193992859567942',
#    'changePercent24Hr': '-1.2410788389768424',
#    'vwap24Hr': '0.1205390318819673',
#    'explorer': 'https://tronscan.org/#/'},
#   {'id': 'polygon',
#    'rank': '17',
#    'symbol': 'MATIC',
#    'name': 'Polygon',
#    'supply': '9906666473.1907880000000000',
#    'maxSupply': '10000000000.0000000000000000',
#    'marketCapUsd': '10009997229.2744395843442016',
#    'volumeUsd24Hr': '242107544.3918855370332840',
#    'priceUsd': '1.0104304264571017',
#    'changePercent24Hr': '-3.0235618222653849',
#    'vwap24Hr': '1.0422061100359183',
#    'explorer': 'https://etherscan.io/token/0x7D1AfA7B718fb893dB30A3aBc0Cfc608AaCfeBB0'},
#   {'id': 'internet-computer',
#    'rank': '18',
#    'symbol': 'ICP',
#    'name': 'Internet Computer',
#    'supply': '461012211.7845339000000000',
#    'maxSupply': None,
#    'marketCapUsd': '8535296609.3176965171280547',
#    'volumeUsd24Hr': '311954568.8677936365722989',
#    'priceUsd': '18.5142527489204350',
#    'changePercent24Hr': '-4.7334522159094963',
#    'vwap24Hr': '19.6061320604906664',
#    'explorer': 'https://www.dfinityexplorer.org/#/'},
#   {'id': 'near-protocol',
#    'rank': '19',
#    'symbol': 'NEAR',
#    'name': 'NEAR Protocol',
#    'supply': '1053121449.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '7620330252.5555550021167613',
#    'volumeUsd24Hr': '255500863.8017148443881820',
#    'priceUsd': '7.2359463002026037',
#    'changePercent24Hr': '-7.6935492727309978',
#    'vwap24Hr': '7.5982321250063395',
#    'explorer': 'https://explorer.nearprotocol.com/'},
#   {'id': 'uniswap',
#    'rank': '20',
#    'symbol': 'UNI',
#    'name': 'Uniswap',
#    'supply': '598736139.7100000000000000',
#    'maxSupply': '1000000000.0000000000000000',
#    'marketCapUsd': '7336075779.4629592307675166',
#    'volumeUsd24Hr': '101721754.4811671141753744',
#    'priceUsd': '12.2526022615174255',
#    'changePercent24Hr': '-2.8676240075804000',
#    'vwap24Hr': '12.5529620020432722',
#    'explorer': 'https://etherscan.io/token/0x1f9840a85d5af5bf1d1762f925bdaddc4201f984'},
#   {'id': 'litecoin',
#    'rank': '21',
#    'symbol': 'LTC',
#    'name': 'Litecoin',
#    'supply': '74327168.6075049300000000',
#    'maxSupply': '84000000.0000000000000000',
#    'marketCapUsd': '6976521925.2112560826635470',
#    'volumeUsd24Hr': '565081244.7917984947384538',
#    'priceUsd': '93.8623393829484014',
#    'changePercent24Hr': '-2.4042083972509067',
#    'vwap24Hr': '95.7327626847325012',
#    'explorer': 'http://explorer.litecoin.net/chain/Litecoin'},
#   {'id': 'unus-sed-leo',
#    'rank': '22',
#    'symbol': 'LEO',
#    'name': 'UNUS SED LEO',
#    'supply': '926931427.9000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '5629449462.9119163179252342',
#    'volumeUsd24Hr': '159952.6861946921388854',
#    'priceUsd': '6.0732102650415661',
#    'changePercent24Hr': '-0.0784802553065100',
#    'vwap24Hr': '6.0629252154030202',
#    'explorer': 'https://eospark.com/account/bitfinexleo1'},
#   {'id': 'multi-collateral-dai',
#    'rank': '23',
#    'symbol': 'DAI',
#    'name': 'Multi Collateral DAI',
#    'supply': '5347888595.7464075000000000',
#    'maxSupply': None,
#    'marketCapUsd': '5333120377.2836582505055884',
#    'volumeUsd24Hr': '653330238.9988195416333014',
#    'priceUsd': '0.9972384954925023',
#    'changePercent24Hr': '-0.3339986887535742',
#    'vwap24Hr': '0.9971619122498329',
#    'explorer': 'https://etherscan.io/token/0x89d24a6b4ccb1b6faa2625fe562bdd9a23260359'},
#   {'id': 'stacks',
#    'rank': '24',
#    'symbol': 'STX',
#    'name': 'Stacks',
#    'supply': '1446427874.4571350000000000',
#    'maxSupply': '1818000000.0000000000000000',
#    'marketCapUsd': '4844976798.5380638006761370',
#    'volumeUsd24Hr': '43810846.6037941211013970',
#    'priceUsd': '3.3496152031475836',
#    'changePercent24Hr': '-2.9206896142405515',
#    'vwap24Hr': '3.4530722860469395',
#    'explorer': 'https://explorer.xinfin.network/'},
#   {'id': 'filecoin',
#    'rank': '25',
#    'symbol': 'FIL',
#    'name': 'Filecoin',
#    'supply': '525282244.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '4792742262.7817320161295592',
#    'volumeUsd24Hr': '251254161.0420381700146649',
#    'priceUsd': '9.1241276809305818',
#    'changePercent24Hr': '-2.4886753892189115',
#    'vwap24Hr': '9.2621679899248922',
#    'explorer': 'https://protocol.ai'},
#   {'id': 'ethereum-classic',
#    'rank': '26',
#    'symbol': 'ETC',
#    'name': 'Ethereum Classic',
#    'supply': '146110555.5363162000000000',
#    'maxSupply': '210700000.0000000000000000',
#    'marketCapUsd': '4651270642.3750293931020816',
#    'volumeUsd24Hr': '105585695.0807299714992187',
#    'priceUsd': '31.8339125144106557',
#    'changePercent24Hr': '-1.0415939254028741',
#    'vwap24Hr': '31.8780343198644662',
#    'explorer': 'http://gastracker.io/'},
#   {'id': 'render-token',
#    'rank': '27',
#    'symbol': 'RNDR',
#    'name': 'Render Token',
#    'supply': '369614008.1087959400000000',
#    'maxSupply': '536870912.0000000000000000',
#    'marketCapUsd': '3993057017.2091968034895384',
#    'volumeUsd24Hr': '37718889.9771160571505887',
#    'priceUsd': '10.8033162423699046',
#    'changePercent24Hr': '-1.8705512054181483',
#    'vwap24Hr': '11.3477146811172552',
#    'explorer': 'https://etherscan.io/token/0x6de037ef9ad2725eb40118bb1702ebb27e4aeb24'},
#   {'id': 'okb',
#    'rank': '28',
#    'symbol': 'OKB',
#    'name': 'OKB',
#    'supply': '60000000.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '3892859265.2771122860000000',
#    'volumeUsd24Hr': '1042170.8740198935580218',
#    'priceUsd': '64.8809877546185381',
#    'changePercent24Hr': '-1.8960319617930158',
#    'vwap24Hr': '65.9918973822448309',
#    'explorer': 'https://etherscan.io/token/0x75231f58b43240c9718dd58b4967c5114342a86c'},
#   {'id': 'stellar',
#    'rank': '29',
#    'symbol': 'XLM',
#    'name': 'Stellar',
#    'supply': '28681978352.6240540000000000',
#    'maxSupply': '50001806812.0000000000000000',
#    'marketCapUsd': '3847009982.6729677929189379',
#    'volumeUsd24Hr': '67553894.9234955044746045',
#    'priceUsd': '0.1341263819174807',
#    'changePercent24Hr': '-2.7406775342828845',
#    'vwap24Hr': '0.1363356631477942',
#    'explorer': 'https://dashboard.stellar.org/'},
#   {'id': 'the-graph',
#    'rank': '30',
#    'symbol': 'GRT',
#    'name': 'The Graph',
#    'supply': '9456178825.3094500000000000',
#    'maxSupply': None,
#    'marketCapUsd': '3752516417.7368837393894591',
#    'volumeUsd24Hr': '94357456.1752210038929190',
#    'priceUsd': '0.3968322180724077',
#    'changePercent24Hr': '0.2312732168378354',
#    'vwap24Hr': '0.4034612565606844',
#    'explorer': 'https://etherscan.io/token/0xc944e90c64b2c07662a292be6244bdf05cda44a7'},
#   {'id': 'crypto-com-coin',
#    'rank': '31',
#    'symbol': 'CRO',
#    'name': 'Crypto.com Coin',
#    'supply': '25263013692.0000000000000000',
#    'maxSupply': '30263013692.0000000000000000',
#    'marketCapUsd': '3703445204.1845426602646940',
#    'volumeUsd24Hr': '12291334.4650693832048128',
#    'priceUsd': '0.1465955427699945',
#    'changePercent24Hr': '0.2330738312843985',
#    'vwap24Hr': '0.1475576109565586',
#    'explorer': 'https://etherscan.io/token/0xa0b73e1ff0b80914ab6fe0444e65848c4c34450b'},
#   {'id': 'vechain',
#    'rank': '32',
#    'symbol': 'VET',
#    'name': 'VeChain',
#    'supply': '72714516834.0000000000000000',
#    'maxSupply': '86712634466.0000000000000000',
#    'marketCapUsd': '3196182902.7284589342682608',
#    'volumeUsd24Hr': '52891448.8557147108384916',
#    'priceUsd': '0.0439552243745912',
#    'changePercent24Hr': '-0.7952503227428564',
#    'vwap24Hr': '0.0445016615347045',
#    'explorer': 'https://explore.veforge.com/'},
#   {'id': 'cosmos',
#    'rank': '33',
#    'symbol': 'ATOM',
#    'name': 'Cosmos',
#    'supply': '248453201.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '3117847939.7813280651353229',
#    'volumeUsd24Hr': '243900035.7154587765059874',
#    'priceUsd': '12.5490350988930429',
#    'changePercent24Hr': '1.9129909820702497',
#    'vwap24Hr': '12.4609979368698653',
#    'explorer': 'https://www.mintscan.io/'},
#   {'id': 'theta',
#    'rank': '34',
#    'symbol': 'THETA',
#    'name': 'THETA',
#    'supply': '1000000000.0000000000000000',
#    'maxSupply': '1000000000.0000000000000000',
#    'marketCapUsd': '3022994168.5007815000000000',
#    'volumeUsd24Hr': '49137334.5275407047999094',
#    'priceUsd': '3.0229941685007815',
#    'changePercent24Hr': '-3.3059367646267656',
#    'vwap24Hr': '3.0520813206402225',
#    'explorer': 'https://explorer.thetatoken.org/'},
#   {'id': 'thorchain',
#    'rank': '35',
#    'symbol': 'RUNE',
#    'name': 'THORChain',
#    'supply': '336620216.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '3009844090.0086757443876816',
#    'volumeUsd24Hr': '190671007.6405273542090139',
#    'priceUsd': '8.9413646208600726',
#    'changePercent24Hr': '-4.7585162580757628',
#    'vwap24Hr': '9.4847813348716816',
#    'explorer': 'https://explorer.binance.org/asset/RUNE-B1A'},
#   {'id': 'maker',
#    'rank': '36',
#    'symbol': 'MKR',
#    'name': 'Maker',
#    'supply': '924359.6736397800000000',
#    'maxSupply': '1005577.0000000000000000',
#    'marketCapUsd': '2982329737.1904318985411865',
#    'volumeUsd24Hr': '62080899.3006062357055390',
#    'priceUsd': '3226.3736965581173022',
#    'changePercent24Hr': '-0.2294496690901475',
#    'vwap24Hr': '3216.6569078884778298',
#    'explorer': 'https://etherscan.io/token/Maker'},
#   {'id': 'fantom',
#    'rank': '37',
#    'symbol': 'FTM',
#    'name': 'Fantom',
#    'supply': '2803634835.5265927000000000',
#    'maxSupply': '3175000000.0000000000000000',
#    'marketCapUsd': '2847114016.4042050597319486',
#    'volumeUsd24Hr': '186577659.2048033984683660',
#    'priceUsd': '1.0155081468979700',
#    'changePercent24Hr': '-4.8408899796509430',
#    'vwap24Hr': '1.0543381762851899',
#    'explorer': 'https://etherscan.io/token/0x4e15361fd6b4bb609fa63c81a2be19d873717870'},
#   {'id': 'injective-protocol',
#    'rank': '38',
#    'symbol': 'INJ',
#    'name': 'Injective',
#    'supply': '73005554.3300000000000000',
#    'maxSupply': '100000000.0000000000000000',
#    'marketCapUsd': '2767215861.3671740676173838',
#    'volumeUsd24Hr': '89945497.7289021128290142',
#    'priceUsd': '37.9041825894341383',
#    'changePercent24Hr': '-2.7259509381872914',
#    'vwap24Hr': '38.5920654742404602',
#    'explorer': 'https://etherscan.io/token/0xe28b3b32b6c345a34ff64674606124dd5aceca30'},
#   {'id': 'arweave',
#    'rank': '39',
#    'symbol': 'AR',
#    'name': 'Arweave',
#    'supply': '65454185.0000000000000000',
#    'maxSupply': '66000000.0000000000000000',
#    'marketCapUsd': '2708187272.6416927659202220',
#    'volumeUsd24Hr': '51867858.2817259493888775',
#    'priceUsd': '41.3753111835659212',
#    'changePercent24Hr': '0.2965501730186531',
#    'vwap24Hr': '41.7634917296986129',
#    'explorer': 'https://viewblock.io/arweave'},
#   {'id': 'lido-dao',
#    'rank': '40',
#    'symbol': 'LDO',
#    'name': 'Lido DAO',
#    'supply': '891700325.0543096000000000',
#    'maxSupply': '1000000000.0000000000000000',
#    'marketCapUsd': '2659534229.0085921535013721',
#    'volumeUsd24Hr': '8126398.8858712039664656',
#    'priceUsd': '2.9825426259058630',
#    'changePercent24Hr': '-4.9375176050403024',
#    'vwap24Hr': '3.1541374738207001',
#    'explorer': 'https://etherscan.io/token/0x5a98fcbea516cf06857215779fd812ca3bef1b32'},
#   {'id': 'monero',
#    'rank': '41',
#    'symbol': 'XMR',
#    'name': 'Monero',
#    'supply': '18412233.1642821700000000',
#    'maxSupply': None,
#    'marketCapUsd': '2554494225.3609636384259614',
#    'volumeUsd24Hr': '47390397.1207899194273365',
#    'priceUsd': '138.7389678681898569',
#    'changePercent24Hr': '3.5054718307934916',
#    'vwap24Hr': '137.3053589228412742',
#    'explorer': 'http://moneroblocks.info/'},
#   {'id': 'fetch',
#    'rank': '42',
#    'symbol': 'FET',
#    'name': 'Fetch.ai',
#    'supply': '839758747.7594593000000000',
#    'maxSupply': None,
#    'marketCapUsd': '2523671401.9259281545341039',
#    'volumeUsd24Hr': '568689095.3660432798345871',
#    'priceUsd': '3.0052338349070812',
#    'changePercent24Hr': '3.8420567412781443',
#    'vwap24Hr': '3.1069347681845110',
#    'explorer': 'https://etherscan.io/token/0x1d287cc25dad7ccaf76a26bc660c5f7c8e2a05bd'},
#   {'id': 'algorand',
#    'rank': '43',
#    'symbol': 'ALGO',
#    'name': 'Algorand',
#    'supply': '8066790016.0592870000000000',
#    'maxSupply': '10000000000.0000000000000000',
#    'marketCapUsd': '2177009734.8395505081601875',
#    'volumeUsd24Hr': '72492057.1189795253639538',
#    'priceUsd': '0.2698731131597055',
#    'changePercent24Hr': '-2.9449124170161031',
#    'vwap24Hr': '0.2795196385211488',
#    'explorer': 'https://algoexplorer.io/'},
#   {'id': 'flow',
#    'rank': '44',
#    'symbol': 'FLOW',
#    'name': 'Flow',
#    'supply': '1494854696.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '2060806991.7323038742450832',
#    'volumeUsd24Hr': '45208007.3350126291495295',
#    'priceUsd': '1.3786002059241642',
#    'changePercent24Hr': '-3.8416622351439682',
#    'vwap24Hr': '1.4224728433851647',
#    'explorer': 'https://flowscan.org/'},
#   {'id': 'gala',
#    'rank': '45',
#    'symbol': 'GALA',
#    'name': 'Gala',
#    'supply': '29775512979.1718670000000000',
#    'maxSupply': None,
#    'marketCapUsd': '1959989842.5980235370981678',
#    'volumeUsd24Hr': '132539730.6371706529588113',
#    'priceUsd': '0.0658255608885411',
#    'changePercent24Hr': '-2.6109751030808223',
#    'vwap24Hr': '0.0671241674937521',
#    'explorer': 'https://ethplorer.io/es/address/0x15d4c048f83bd7e37d49ea4c83a07267ec4203da#chart=candlestick'},
#   {'id': 'aave',
#    'rank': '46',
#    'symbol': 'AAVE',
#    'name': 'Aave',
#    'supply': '14763809.3572999600000000',
#    'maxSupply': '16000000.0000000000000000',
#    'marketCapUsd': '1840927863.5418525377947446',
#    'volumeUsd24Hr': '63392406.3391824186924700',
#    'priceUsd': '124.6919286878766452',
#    'changePercent24Hr': '-3.5170216047837440',
#    'vwap24Hr': '128.3598604279962449',
#    'explorer': 'https://etherscan.io/token/0x80fB784B7eD66730e8b1DBd9820aFD29931aab03'},
#   {'id': 'conflux-network',
#    'rank': '47',
#    'symbol': 'CFX',
#    'name': 'Conflux',
#    'supply': '3843897296.4700000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '1838699253.1739435703726259',
#    'volumeUsd24Hr': '111513236.8578720156104260',
#    'priceUsd': '0.4783424507367802',
#    'changePercent24Hr': '-1.1791936730481509',
#    'vwap24Hr': '0.4863676931113684',
#    'explorer': 'http://www.confluxscan.io/'},
#   {'id': 'bitcoin-sv',
#    'rank': '48',
#    'symbol': 'BSV',
#    'name': 'Bitcoin SV',
#    'supply': '19664756.2500000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '1806039367.4936356214103431',
#    'volumeUsd24Hr': '24970458.7711265397126467',
#    'priceUsd': '91.8414316726471309',
#    'changePercent24Hr': '2.5446794695613416',
#    'vwap24Hr': '90.1442065824539319',
#    'explorer': 'https://bsvexplorer.io/'},
#   {'id': 'hedera-hashgraph',
#    'rank': '49',
#    'symbol': 'HBAR',
#    'name': 'Hedera Hashgraph',
#    'supply': '14832756028.0000000000000000',
#    'maxSupply': '50000000000.0000000000000000',
#    'marketCapUsd': '1692379101.9579210240303080',
#    'volumeUsd24Hr': '46414360.4758059898851886',
#    'priceUsd': '0.1140974137755110',
#    'changePercent24Hr': '-3.9365424452465268',
#    'vwap24Hr': '0.1165444260231293',
#    'explorer': 'https://hash-hash.info/'},
#   {'id': 'quant',
#    'rank': '50',
#    'symbol': 'QNT',
#    'name': 'Quant',
#    'supply': '12072738.0000000000000000',
#    'maxSupply': '14881364.0000000000000000',
#    'marketCapUsd': '1643872540.3619632766619348',
#    'volumeUsd24Hr': '19792930.2148723597888514',
#    'priceUsd': '136.1640201553254346',
#    'changePercent24Hr': '-3.5159525761640801',
#    'vwap24Hr': '139.3725349061289247',
#    'explorer': 'https://etherscan.io/token/0x4a220e6096b25eadb88358cb44068a3248254675'},
#   {'id': 'singularitynet',
#    'rank': '51',
#    'symbol': 'AGIX',
#    'name': 'SingularityNET',
#    'supply': '1279380811.6426191000000000',
#    'maxSupply': '2000000000.0000000000000000',
#    'marketCapUsd': '1632286855.6287864148761596',
#    'volumeUsd24Hr': '36839537.0532653109737879',
#    'priceUsd': '1.2758412825756431',
#    'changePercent24Hr': '7.5015621481729193',
#    'vwap24Hr': '1.2509856717683567',
#    'explorer': 'https://etherscan.io/token/0x8eb24319393716668d768dcec29356ae9cffe285'},
#   {'id': 'axie-infinity',
#    'rank': '52',
#    'symbol': 'AXS',
#    'name': 'Axie Infinity',
#    'supply': '142037746.2970986000000000',
#    'maxSupply': '270000000.0000000000000000',
#    'marketCapUsd': '1563177026.3570688327062145',
#    'volumeUsd24Hr': '44774287.4740726096933388',
#    'priceUsd': '11.0053634833616041',
#    'changePercent24Hr': '-2.9984926020619337',
#    'vwap24Hr': '11.2720507701491535',
#    'explorer': 'https://etherscan.io/token/0xf5d669627376ebd411e34b98f19c868c8aba5ada'},
#   {'id': 'the-sandbox',
#    'rank': '53',
#    'symbol': 'SAND',
#    'name': 'The Sandbox',
#    'supply': '2251731926.2233224000000000',
#    'maxSupply': '3000000000.0000000000000000',
#    'marketCapUsd': '1536823202.3503938193927624',
#    'volumeUsd24Hr': '74488525.2953279730559200',
#    'priceUsd': '0.6825071778983937',
#    'changePercent24Hr': '-4.4082314493060094',
#    'vwap24Hr': '0.7043663797469614',
#    'explorer': 'https://etherscan.io/token/0x3845badAde8e6dFF049820680d1F14bD3903a5d0'},
#   {'id': 'elrond-egld',
#    'rank': '54',
#    'symbol': 'EGLD',
#    'name': 'MultiversX',
#    'supply': '24184559.1898415400000000',
#    'maxSupply': '31415926.0000000000000000',
#    'marketCapUsd': '1466118317.9299038993570576',
#    'volumeUsd24Hr': '25394385.7543051574931870',
#    'priceUsd': '60.6220814868410291',
#    'changePercent24Hr': '-2.9335778066053616',
#    'vwap24Hr': '61.8823245823068994',
#    'explorer': 'https://explorer.elrond.com/'},
#   {'id': 'tezos',
#    'rank': '55',
#    'symbol': 'XTZ',
#    'name': 'Tezos',
#    'supply': '974839642.9751710000000000',
#    'maxSupply': None,
#    'marketCapUsd': '1346090401.5040314261703052',
#    'volumeUsd24Hr': '44195528.4248639494430256',
#    'priceUsd': '1.3808326438139284',
#    'changePercent24Hr': '1.9378795821768814',
#    'vwap24Hr': '1.3759286975034495',
#    'explorer': 'https://tzkt.io/'},
#   {'id': 'mina',
#    'rank': '56',
#    'symbol': 'MINA',
#    'name': 'Mina',
#    'supply': '1070802276.8400393000000000',
#    'maxSupply': None,
#    'marketCapUsd': '1338338787.1396871325199502',
#    'volumeUsd24Hr': '34174495.6571173381172633',
#    'priceUsd': '1.2498467887920017',
#    'changePercent24Hr': '-1.8121552238906113',
#    'vwap24Hr': '1.2756952715604976',
#    'explorer': 'https://minaexplorer.com/'},
#   {'id': 'ecash',
#    'rank': '57',
#    'symbol': 'XEC',
#    'name': 'eCash',
#    'supply': '19665554673092.0000000000000000',
#    'maxSupply': '21000000000000.0000000000000000',
#    'marketCapUsd': '1290514824.9316065964046284',
#    'volumeUsd24Hr': '20877530.6101999239039010',
#    'priceUsd': '0.0000656231083427',
#    'changePercent24Hr': '-0.9513611655821555',
#    'vwap24Hr': '0.0000656938808952',
#    'explorer': 'https://explorer.bitcoinabc.org/'},
#   {'id': 'decentraland',
#    'rank': '58',
#    'symbol': 'MANA',
#    'name': 'Decentraland',
#    'supply': '1908319865.3915880000000000',
#    'maxSupply': None,
#    'marketCapUsd': '1268894022.2461418063390658',
#    'volumeUsd24Hr': '31163141.3274647539509307',
#    'priceUsd': '0.6649273244272203',
#    'changePercent24Hr': '-2.9705534082092566',
#    'vwap24Hr': '0.6798634730736596',
#    'explorer': 'https://etherscan.io/token/decentraland'},
#   {'id': 'chiliz',
#    'rank': '59',
#    'symbol': 'CHZ',
#    'name': 'Chiliz',
#    'supply': '8888290306.5249610000000000',
#    'maxSupply': '8888888888.0000000000000000',
#    'marketCapUsd': '1260017024.0732296483646224',
#    'volumeUsd24Hr': '38736933.1441675375014692',
#    'priceUsd': '0.1417614614981963',
#    'changePercent24Hr': '-3.3072212329353997',
#    'vwap24Hr': '0.1452269606803969',
#    'explorer': 'https://etherscan.io/token/0x3506424f91fd33084466f402d5d97f05f8e3b4af'},
#   {'id': 'akash-network',
#    'rank': '60',
#    'symbol': 'AKT',
#    'name': 'Akash Network',
#    'supply': '230907433.3108150000000000',
#    'maxSupply': '388539008.0000000000000000',
#    'marketCapUsd': '1230520754.1845144445486155',
#    'volumeUsd24Hr': '1407376.7671624282652416',
#    'priceUsd': '5.3290651432955866',
#    'changePercent24Hr': '-0.5803493484054164',
#    'vwap24Hr': '5.3838348550479852',
#    'explorer': 'https://akash.bigdipper.live/'},
#   {'id': 'eos',
#    'rank': '61',
#    'symbol': 'EOS',
#    'name': 'EOS',
#    'supply': '1120460954.5722000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '1191845838.8660615199473440',
#    'volumeUsd24Hr': '86058672.3747714568496547',
#    'priceUsd': '1.0637102828104499',
#    'changePercent24Hr': '-2.7339488860909969',
#    'vwap24Hr': '1.0731344316461536',
#    'explorer': 'https://bloks.io/'},
#   {'id': 'synthetix-network-token',
#    'rank': '62',
#    'symbol': 'SNX',
#    'name': 'Synthetix',
#    'supply': '233716733.4900000000000000',
#    'maxSupply': '212424133.0000000000000000',
#    'marketCapUsd': '1139054395.4930989492769360',
#    'volumeUsd24Hr': '48317633.1914242731576438',
#    'priceUsd': '4.8736535826256338',
#    'changePercent24Hr': '-1.9078581479524942',
#    'vwap24Hr': '4.9216311028914841',
#    'explorer': 'https://etherscan.io/token/0xc011a72400e58ecd99ee497cf89e3775d4bd732f'},
#   {'id': 'kucoin-token',
#    'rank': '63',
#    'symbol': 'KCS',
#    'name': 'KuCoin Token',
#    'supply': '96287258.2890287500000000',
#    'maxSupply': '170118638.0000000000000000',
#    'marketCapUsd': '1122946281.4598937460460030',
#    'volumeUsd24Hr': '9325754.7884505374170966',
#    'priceUsd': '11.6624598250487885',
#    'changePercent24Hr': '-5.2527177468040208',
#    'vwap24Hr': '12.2294990757623404',
#    'explorer': 'https://etherscan.io/token/0xf34960d9d60be18cc1d5afc1a6f012a723a28811'},
#   {'id': 'neo',
#    'rank': '64',
#    'symbol': 'NEO',
#    'name': 'Neo',
#    'supply': '70538831.0000000000000000',
#    'maxSupply': '100000000.0000000000000000',
#    'marketCapUsd': '1115307276.0348335176671575',
#    'volumeUsd24Hr': '22829321.3655885455245898',
#    'priceUsd': '15.8112526139656825',
#    'changePercent24Hr': '-2.6426616626655297',
#    'vwap24Hr': '16.0447610351432849',
#    'explorer': 'https://neotracker.io'},
#   {'id': 'iota',
#    'rank': '65',
#    'symbol': 'IOTA',
#    'name': 'IOTA',
#    'supply': '3172092163.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '1100180435.3386855491545877',
#    'volumeUsd24Hr': '19403814.5637915996093525',
#    'priceUsd': '0.3468311697155079',
#    'changePercent24Hr': '-2.7552931068250903',
#    'vwap24Hr': '0.3597688299934986',
#    'explorer': 'https://thetangle.org/'},
#   {'id': 'kava',
#    'rank': '66',
#    'symbol': 'KAVA',
#    'name': 'Kava',
#    'supply': '1082860636.0000000000000000',
#    'maxSupply': '1082860679.0000000000000000',
#    'marketCapUsd': '1093733716.1969861512468456',
#    'volumeUsd24Hr': '40642428.0632954938160837',
#    'priceUsd': '1.0100410706932246',
#    'changePercent24Hr': '-1.0625046292448997',
#    'vwap24Hr': '1.0061588806766505',
#    'explorer': 'https://www.mintscan.io/kava'},
#   {'id': 'pancakeswap',
#    'rank': '67',
#    'symbol': 'CAKE',
#    'name': 'PancakeSwap',
#    'supply': '244672128.8103295000000000',
#    'maxSupply': '450000000.0000000000000000',
#    'marketCapUsd': '1075740303.4182600032246907',
#    'volumeUsd24Hr': '35707425.7286573321396552',
#    'priceUsd': '4.3966605785826011',
#    'changePercent24Hr': '0.6472692252317295',
#    'vwap24Hr': '4.3793261862607927',
#    'explorer': 'https://bscscan.com/token/0x0e09fabb73bd3ade0a17ecc321fd13a19e81ce82'},
#   {'id': 'trueusd',
#    'rank': '68',
#    'symbol': 'TUSD',
#    'name': 'TrueUSD',
#    'supply': '988455467.0100000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '989502983.0421459985635646',
#    'volumeUsd24Hr': '20451476.4594410069209225',
#    'priceUsd': '1.0010597503550814',
#    'changePercent24Hr': '-1.8902515946067874',
#    'vwap24Hr': '1.0134466820332430',
#    'explorer': 'https://etherscan.io/token/0x8dd5fbce2f6a956c3022ba3663759011dd51e73e'},
#   {'id': 'pendle',
#    'rank': '69',
#    'symbol': 'PENDLE',
#    'name': 'Pendle',
#    'supply': '238185588.2446348700000000',
#    'maxSupply': '258446029.0000000000000000',
#    'marketCapUsd': '986601954.1567741052233514',
#    'volumeUsd24Hr': '4515544.1307426741827550',
#    'priceUsd': '4.1421563807775734',
#    'changePercent24Hr': '4.6997483452365744',
#    'vwap24Hr': '4.1389638487376856',
#    'explorer': 'https://etherscan.io/token/0x808507121b80c02388fad14726482e061b8da827'},
#   {'id': 'helium',
#    'rank': '70',
#    'symbol': 'HNT',
#    'name': 'Helium',
#    'supply': '160875441.8242133300000000',
#    'maxSupply': '223000000.0000000000000000',
#    'marketCapUsd': '982153996.0509597496076587',
#    'volumeUsd24Hr': '2893531.7000291460153943',
#    'priceUsd': '6.1050585777047790',
#    'changePercent24Hr': '-2.5468663275143478',
#    'vwap24Hr': '6.2104491021750894',
#    'explorer': 'https://explorer.helium.com/'},
#   {'id': 'aioz-network',
#    'rank': '71',
#    'symbol': 'AIOZ',
#    'name': 'AIOZ Network',
#    'supply': '1080584737.2439904000000000',
#    'maxSupply': None,
#    'marketCapUsd': '965134374.2699400540398931',
#    'volumeUsd24Hr': '12940647.8430052176909914',
#    'priceUsd': '0.8931593617835986',
#    'changePercent24Hr': '-3.4590500532590573',
#    'vwap24Hr': '0.9559284710497724',
#    'explorer': 'https://etherscan.io/token/0x626e8036deb333b408be468f951bdb42433cbf18'},
#   {'id': 'klaytn',
#    'rank': '72',
#    'symbol': 'KLAY',
#    'name': 'Klaytn',
#    'supply': '3569322484.4565535000000000',
#    'maxSupply': None,
#    'marketCapUsd': '947343929.3424617344429105',
#    'volumeUsd24Hr': '7662981.2127499589801310',
#    'priceUsd': '0.2654128153081969',
#    'changePercent24Hr': '-5.3453345376825484',
#    'vwap24Hr': '0.2741767097819654',
#    'explorer': 'https://scope.klaytn.com/blocks'},
#   {'id': 'oasis-network',
#    'rank': '73',
#    'symbol': 'ROSE',
#    'name': 'Oasis Network',
#    'supply': '6713599876.0000000000000000',
#    'maxSupply': '10000000000.0000000000000000',
#    'marketCapUsd': '946455130.9804526250310816',
#    'volumeUsd24Hr': '27728156.8888033077102949',
#    'priceUsd': '0.1409758026187816',
#    'changePercent24Hr': '-4.7071769108046287',
#    'vwap24Hr': '0.1465103973866092',
#    'explorer': 'https://www.oasisscan.com/'},
#   {'id': 'gnosis-gno',
#    'rank': '74',
#    'symbol': 'GNO',
#    'name': 'Gnosis',
#    'supply': '2589588.0000000000000000',
#    'maxSupply': '3000000.0000000000000000',
#    'marketCapUsd': '926785057.4091005210406828',
#    'volumeUsd24Hr': '11390520.0048677643131533',
#    'priceUsd': '357.8889991029849231',
#    'changePercent24Hr': '-1.1427447621819973',
#    'vwap24Hr': '362.4693824278173930',
#    'explorer': 'https://etherscan.io/token/Gnosis'},
#   {'id': '0x',
#    'rank': '75',
#    'symbol': 'ZRX',
#    'name': '0x Protocol',
#    'supply': '847496054.8027713000000000',
#    'maxSupply': '1000000000.0000000000000000',
#    'marketCapUsd': '906898153.8469896058455218',
#    'volumeUsd24Hr': '62674263.5116351090781519',
#    'priceUsd': '1.0700912986055638',
#    'changePercent24Hr': '1.0431005791637299',
#    'vwap24Hr': '1.0808084901756976',
#    'explorer': 'https://etherscan.io/token/ZRX'},
#   {'id': 'gatetoken',
#    'rank': '76',
#    'symbol': 'GT',
#    'name': 'GateToken',
#    'supply': '96490073.1090052900000000',
#    'maxSupply': None,
#    'marketCapUsd': '893319826.4760456627435391',
#    'volumeUsd24Hr': '20507074.8477029651310580',
#    'priceUsd': '9.2581526543860947',
#    'changePercent24Hr': '7.8703762985313879',
#    'vwap24Hr': '8.7568612204937409',
#    'explorer': None},
#   {'id': 'wemix',
#    'rank': '77',
#    'symbol': 'WEMIX',
#    'name': 'WEMIX',
#    'supply': '365709618.3174209600000000',
#    'maxSupply': '980000000.0000000000000000',
#    'marketCapUsd': '892204755.4066679136032427',
#    'volumeUsd24Hr': '23383514.1808700311272092',
#    'priceUsd': '2.4396535139315662',
#    'changePercent24Hr': '-6.1695217083313453',
#    'vwap24Hr': '2.4264819620583744',
#    'explorer': 'https://scope.klaytn.com/token/0x5096db80b21ef45230c9e423c373f1fc9c0198dd?tabId=kctTransfer'},
#   {'id': 'nervos-network',
#    'rank': '78',
#    'symbol': 'CKB',
#    'name': 'Nervos Network',
#    'supply': '43772719517.4504200000000000',
#    'maxSupply': None,
#    'marketCapUsd': '867607301.5699473801828103',
#    'volumeUsd24Hr': '36397280.5183340083469517',
#    'priceUsd': '0.0198207310657056',
#    'changePercent24Hr': '-4.1346411364862981',
#    'vwap24Hr': '0.0204543856663175',
#    'explorer': 'https://explorer.nervos.org/'},
#   {'id': 'wootrade',
#    'rank': '79',
#    'symbol': 'WOO',
#    'name': 'WOO',
#    'supply': '1837867859.7621970000000000',
#    'maxSupply': None,
#    'marketCapUsd': '847403074.9947469527876158',
#    'volumeUsd24Hr': '11815956.6719052752501084',
#    'priceUsd': '0.4610794353324145',
#    'changePercent24Hr': '-2.9490727457385719',
#    'vwap24Hr': '0.4753688247263607',
#    'explorer': 'https://etherscan.io/token/0x4691937a7508860f876c9c0a2a617e7d9e945d4b'},
#   {'id': 'curve-dao-token',
#    'rank': '80',
#    'symbol': 'CRV',
#    'name': 'Curve DAO Token',
#    'supply': '1156930125.0000000000000000',
#    'maxSupply': '3303030299.0000000000000000',
#    'marketCapUsd': '804525563.8427046103311000',
#    'volumeUsd24Hr': '7380703.5968172879947651',
#    'priceUsd': '0.6953968493496568',
#    'changePercent24Hr': '-1.3511838346364316',
#    'vwap24Hr': '0.7026585472354118',
#    'explorer': 'https://etherscan.io/token/0xD533a949740bb3306d119CC777fa900bA034cd52'},
#   {'id': 'ribbon-finance',
#    'rank': '81',
#    'symbol': 'RBN',
#    'name': 'Ribbon Finance',
#    'supply': '537093440.4611390000000000',
#    'maxSupply': None,
#    'marketCapUsd': '801869300.4809650192615442',
#    'volumeUsd24Hr': '5397514.1172734002319367',
#    'priceUsd': '1.4929791356090555',
#    'changePercent24Hr': '5.0605604877559576',
#    'vwap24Hr': '1.4654189915637899',
#    'explorer': 'https://etherscan.io/token/0x6123B0049F904d730dB3C36a31167D9d4121fA6B'},
#   {'id': 'ocean-protocol',
#    'rank': '82',
#    'symbol': 'OCEAN',
#    'name': 'Ocean Protocol',
#    'supply': '568381102.7486407000000000',
#    'maxSupply': '1410000000.0000000000000000',
#    'marketCapUsd': '774879928.1134485775098349',
#    'volumeUsd24Hr': '240776378.0275769387777825',
#    'priceUsd': '1.3633105048112927',
#    'changePercent24Hr': '13.3759220527718085',
#    'vwap24Hr': '1.4349240162184541',
#    'explorer': 'https://etherscan.io/token/0x7AFeBBB46fDb47ed17b22ed075Cde2447694fB9e'},
#   {'id': 'bitcoin-gold',
#    'rank': '83',
#    'symbol': 'BTG',
#    'name': 'Bitcoin Gold',
#    'supply': '17513923.5890000000000000',
#    'maxSupply': '21000000.0000000000000000',
#    'marketCapUsd': '771004290.2067734955783453',
#    'volumeUsd24Hr': '132313.5483938633383286',
#    'priceUsd': '44.0223623386720427',
#    'changePercent24Hr': '-0.2322030554483005',
#    'vwap24Hr': '44.3407536582760995',
#    'explorer': 'https://explorer.bitcoingold.org/insight/'},
#   {'id': 'iotex',
#    'rank': '84',
#    'symbol': 'IOTX',
#    'name': 'IoTeX',
#    'supply': '9441378955.0000000000000000',
#    'maxSupply': '10000000000.0000000000000000',
#    'marketCapUsd': '738992855.8163959933099550',
#    'volumeUsd24Hr': '29417498.7908524533487076',
#    'priceUsd': '0.0782717079082010',
#    'changePercent24Hr': '5.6448571272408094',
#    'vwap24Hr': '0.0773588023579340',
#    'explorer': 'https://etherscan.io/token/0x6fb3e0a217407efff7ca062d46c26e5d60a14d69'},
#   {'id': 'nexo',
#    'rank': '85',
#    'symbol': 'NEXO',
#    'name': 'Nexo',
#    'supply': '560000011.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '738005242.7780082858147271',
#    'volumeUsd24Hr': '1738942.7727465744694756',
#    'priceUsd': '1.3178664790740661',
#    'changePercent24Hr': '-3.4606675867380761',
#    'vwap24Hr': '1.3552259894261670',
#    'explorer': 'https://etherscan.io/token/0xb62132e35a6c13ee1ee0f84dc5d40bad8d815206'},
#   {'id': 'celo',
#    'rank': '86',
#    'symbol': 'CELO',
#    'name': 'Celo',
#    'supply': '530956100.0000000000000000',
#    'maxSupply': '1000000000.0000000000000000',
#    'marketCapUsd': '694110029.8348324664165600',
#    'volumeUsd24Hr': '41752468.0040307204867590',
#    'priceUsd': '1.3072832760275896',
#    'changePercent24Hr': '3.8575665180255951',
#    'vwap24Hr': '1.3130203361049921',
#    'explorer': 'https://explorer.celo.org/blocks'},
#   {'id': 'ftx-token',
#    'rank': '87',
#    'symbol': 'FTT',
#    'name': 'FTX Token',
#    'supply': '328895103.8132070000000000',
#    'maxSupply': '352170015.0000000000000000',
#    'marketCapUsd': '679620463.0898334794595234',
#    'volumeUsd24Hr': '17230765.3044879619300144',
#    'priceUsd': '2.0663745224854967',
#    'changePercent24Hr': '-2.6133245169554326',
#    'vwap24Hr': '2.1391135643921073',
#    'explorer': 'https://etherscan.io/token/0x50d1c9771902476076ecfc8b2a83ad6b9355a4c9'},
#   {'id': 'enjin-coin',
#    'rank': '88',
#    'symbol': 'ENJ',
#    'name': 'Enjin Coin',
#    'supply': '1379841765.7600000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '678903779.4563626499168856',
#    'volumeUsd24Hr': '16158206.9166364740931827',
#    'priceUsd': '0.4920156762195343',
#    'changePercent24Hr': '-4.6662715896686153',
#    'vwap24Hr': '0.5101464354654736',
#    'explorer': 'https://etherscan.io/token/0xf629cbd94d3791c9250152bd8dfbdf380e2a3b9c'},
#   {'id': '1inch',
#    'rank': '89',
#    'symbol': '1INCH',
#    'name': '1inch Network',
#    'supply': '1143723500.7828507000000000',
#    'maxSupply': None,
#    'marketCapUsd': '668553885.0956878433075142',
#    'volumeUsd24Hr': '23223564.5566949022605384',
#    'priceUsd': '0.5845415300446997',
#    'changePercent24Hr': '-2.9445013453947096',
#    'vwap24Hr': '0.5976166604780829',
#    'explorer': 'https://etherscan.io/token/0x111111111117dc0aa78b770fa6a738034120c302'},
#   {'id': 'dydx',
#    'rank': '90',
#    'symbol': 'DYDX',
#    'name': 'dYdX',
#    'supply': '183765523.0000000000000000',
#    'maxSupply': '1000000000.0000000000000000',
#    'marketCapUsd': '634902776.3505697714453554',
#    'volumeUsd24Hr': '37655030.7461817912774596',
#    'priceUsd': '3.4549613332560198',
#    'changePercent24Hr': '-5.4797008566186656',
#    'vwap24Hr': '3.5523565587894409',
#    'explorer': None},
#   {'id': 'superfarm',
#    'rank': '91',
#    'symbol': 'SUPER',
#    'name': 'SuperVerse',
#    'supply': '487776093.4169172600000000',
#    'maxSupply': '1000000000.0000000000000000',
#    'marketCapUsd': '625313184.5187564810729970',
#    'volumeUsd24Hr': '6051118.9247899605780024',
#    'priceUsd': '1.2819676752470155',
#    'changePercent24Hr': '-6.0644268298192190',
#    'vwap24Hr': '1.3167012089533225',
#    'explorer': 'https://etherscan.io/token/0xe53ec727dbdeb9e2d5456c3be40cff031ab40a55'},
#   {'id': 'livepeer',
#    'rank': '92',
#    'symbol': 'LPT',
#    'name': 'Livepeer',
#    'supply': '31361484.2529945700000000',
#    'maxSupply': None,
#    'marketCapUsd': '622051093.9800106968943503',
#    'volumeUsd24Hr': '26191802.1391103944888212',
#    'priceUsd': '19.8348741711934051',
#    'changePercent24Hr': '-2.8213576291618457',
#    'vwap24Hr': '20.5566089627639637',
#    'explorer': 'https://explorer.livepeer.org/'},
#   {'id': 'rocket-pool',
#    'rank': '93',
#    'symbol': 'RPL',
#    'name': 'Rocket Pool',
#    'supply': '20217174.1801535400000000',
#    'maxSupply': None,
#    'marketCapUsd': '620218185.5903142796046469',
#    'volumeUsd24Hr': '293866.1476694703796918',
#    'priceUsd': '30.6777881054791413',
#    'changePercent24Hr': '-1.5498291790028099',
#    'vwap24Hr': '30.4223269494111835',
#    'explorer': 'https://etherscan.io/token/0xb4efd85c19999d84251304bda99e90b92300bd93'},
#   {'id': 'compound',
#    'rank': '94',
#    'symbol': 'COMP',
#    'name': 'Compound',
#    'supply': '8094883.9148963500000000',
#    'maxSupply': '10000000.0000000000000000',
#    'marketCapUsd': '619050261.2852173120931317',
#    'volumeUsd24Hr': '35338111.4657310367697884',
#    'priceUsd': '76.4742605074335855',
#    'changePercent24Hr': '-2.7578094036343883',
#    'vwap24Hr': '78.0798590277824164',
#    'explorer': 'https://etherscan.io/token/0xc00e94cb662c3520282e6f5717214004a7f26888'},
#   {'id': 'zilliqa',
#    'rank': '95',
#    'symbol': 'ZIL',
#    'name': 'Zilliqa',
#    'supply': '17372203179.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '615815811.5155569834188871',
#    'volumeUsd24Hr': '22415741.7631872520147244',
#    'priceUsd': '0.0354483426868949',
#    'changePercent24Hr': '-3.2525129368303712',
#    'vwap24Hr': '0.0363255657953989',
#    'explorer': 'https://etherscan.io/token/0x05f4a42e251f2d52b8ed15e9fedaacfcef1fad27'},
#   {'id': 'frax-share',
#    'rank': '96',
#    'symbol': 'FXS',
#    'name': 'Frax Share',
#    'supply': '78569938.8041846500000000',
#    'maxSupply': None,
#    'marketCapUsd': '605632353.4971318786394103',
#    'volumeUsd24Hr': '737568.4693862902585812',
#    'priceUsd': '7.7081942879771695',
#    'changePercent24Hr': '-2.0626952944265641',
#    'vwap24Hr': '7.7998795692040546',
#    'explorer': 'https://etherscan.io/token/0x3432b6a60d23ca0dfca7761b7ab56459d9c964d0'},
#   {'id': 'skale-network',
#    'rank': '97',
#    'symbol': 'SKL',
#    'name': 'SKALE',
#    'supply': '5179144337.0000000000000000',
#    'maxSupply': '7000000000.0000000000000000',
#    'marketCapUsd': '603835675.5507462461257109',
#    'volumeUsd24Hr': '31638873.1661790869871712',
#    'priceUsd': '0.1165898527362757',
#    'changePercent24Hr': '-2.7488090803411709',
#    'vwap24Hr': '0.1193747136095707',
#    'explorer': 'https://etherscan.io/token/0x00c83aecc790e8a4453e5dd3b0b4b3680501a7a7'},
#   {'id': 'siacoin',
#    'rank': '98',
#    'symbol': 'SC',
#    'name': 'Siacoin',
#    'supply': '56725117187.2942350000000000',
#    'maxSupply': None,
#    'marketCapUsd': '602909212.6901866416052674',
#    'volumeUsd24Hr': '42023769.6646281197665957',
#    'priceUsd': '0.0106286111441517',
#    'changePercent24Hr': '4.7224756069981343',
#    'vwap24Hr': '0.0109875409771104',
#    'explorer': 'http://explore.sia.tech/'},
#   {'id': 'xinfin-network',
#    'rank': '99',
#    'symbol': 'XDC',
#    'name': 'XinFin Network',
#    'supply': '12293293518.5500000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '591424295.8608324783719399',
#    'volumeUsd24Hr': '4364832.4483672841850763',
#    'priceUsd': '0.0481095074292663',
#    'changePercent24Hr': '-3.6133179287533632',
#    'vwap24Hr': '0.0502746976057973',
#    'explorer': 'https://etherscan.io/token/0x41ab1b6fcbb2fa9dced81acbdec13ea6315f2bf2'},
#   {'id': 'trust-wallet-token',
#    'rank': '100',
#    'symbol': 'TWT',
#    'name': 'Trust Wallet Token',
#    'supply': '416649900.0000000000000000',
#    'maxSupply': '1000000000.0000000000000000',
#    'marketCapUsd': '586872231.7758046952507400',
#    'volumeUsd24Hr': '8884684.3786850119563746',
#    'priceUsd': '1.4085500363153926',
#    'changePercent24Hr': '-1.1144111001794857',
#    'vwap24Hr': '1.4111586031044828',
#    'explorer': 'https://explorer.binance.org/asset/TWT-8C2'}],
#  'timestamp': 1711572567735}

# %%
## Transformation( Restructuring and Data Cleaning)

# %%
data = pd.json_normalize(responsedata, "data")
data.head()
# Out:
#              id rank symbol      name                         supply  \
# 0       bitcoin    1    BTC   Bitcoin      19658368.0000000000000000
# 1      ethereum    2    ETH  Ethereum     120077426.1898597300000000
# 2        tether    3   USDT    Tether  103618183617.7160800000000000
# 3  binance-coin    4    BNB       BNB     166801148.0000000000000000
# 4        solana    5    SOL    Solana     443884942.2473194000000000
#
#                     maxSupply                    marketCapUsd  \
# 0   21000000.0000000000000000  1355165909044.6780711946191232
# 1                        None   421345628047.0649051305278377
# 2                        None   103601221120.5180664422074242
# 3  166801148.0000000000000000    95086174456.6936736366821232
# 4                        None    81882191088.5053842368055237
#
#                   volumeUsd24Hr                priceUsd    changePercent24Hr  \
# 0  12006398229.6472977917543412  68935.8297211995457199  -1.2559745009359602
# 1   6982423467.7926447631014626   3508.9495287886725271  -1.8886614233219535
# 2  28072783650.2279472476164235      0.9998362980646274  -0.0492353998425023
# 3    477060035.9600063698535309    570.0570745274107684  -1.3700083734304190
# 4   1416695336.7724362183967011    184.4671519469634969  -2.3235182242782317
#
#                  vwap24Hr                                           explorer
# 0  69867.2512524566142959                           https://blockchain.info/
# 1   3564.9111712248007983                              https://etherscan.io/
# 2      0.9999288321105012             https://www.omniexplorer.info/asset/31
# 3    575.8235705316241787  https://etherscan.io/token/0xB8c77482e45F1F44d...
# 4    186.7407969824341138                       https://explorer.solana.com/

# %%
data.info() # fill description of the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 100 non-null    object
#  1   rank               100 non-null    object
#  2   symbol             100 non-null    object
#  3   name               100 non-null    object
#  4   supply             100 non-null    object
#  5   maxSupply          55 non-null     object
#  6   marketCapUsd       100 non-null    object
#  7   volumeUsd24Hr      100 non-null    object
#  8   priceUsd           100 non-null    object
#  9   changePercent24Hr  100 non-null    object
#  10  vwap24Hr           100 non-null    object
#  11  explorer           98 non-null     object
# dtypes: object(12)
# memory usage: 9.5+ KB

# %% [markdown]
# ## Convert cateforical data into Numerical Data

# %%
def convert_columns_to_datatypes(df,column_datatypes):
    for column, datatype in column_datatypes.items():
        if column in df.columns:
            df[column] = df[column].astype(datatype)
    return df

# %%
column_datatypes ={
    'rank': int,
    'supply': float,
    'maxSupply': float,
    'marketCapUsd': float,
    'volumeUsd24Hr':float,
    'priceUsd':float,
    'changePercent24Hr':float,
    'vwap24Hr':float
}

data = convert_columns_to_datatypes(data,column_datatypes)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 100 non-null    object
#  1   rank               100 non-null    int32
#  2   symbol             100 non-null    object
#  3   name               100 non-null    object
#  4   supply             100 non-null    float64
#  5   maxSupply          55 non-null     float64
#  6   marketCapUsd       100 non-null    float64
#  7   volumeUsd24Hr      100 non-null    float64
#  8   priceUsd           100 non-null    float64
#  9   changePercent24Hr  100 non-null    float64
#  10  vwap24Hr           100 non-null    float64
#  11  explorer           98 non-null     object
# dtypes: float64(7), int32(1), object(4)
# memory usage: 9.1+ KB

# %% [markdown]
# ## Dealing with Missing Data

# %%
data["maxSupply"] = data["maxSupply"].fillna(0)
data["vwap24Hr"] = data["vwap24Hr"].fillna(0)
data["explorer"] = data["explorer"].fillna('na')

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 100 non-null    object
#  1   rank               100 non-null    int32
#  2   symbol             100 non-null    object
#  3   name               100 non-null    object
#  4   supply             100 non-null    float64
#  5   maxSupply          100 non-null    float64
#  6   marketCapUsd       100 non-null    float64
#  7   volumeUsd24Hr      100 non-null    float64
#  8   priceUsd           100 non-null    float64
#  9   changePercent24Hr  100 non-null    float64
#  10  vwap24Hr           100 non-null    float64
#  11  explorer           100 non-null    object
# dtypes: float64(7), int32(1), object(4)
# memory usage: 9.1+ KB

# %% [markdown]
# ## Round numbers to 2 decimal places

# %%
## function to convert to two decimal places
def round_to_decimal_places(number):
    return round(number,2)

# %%
## columns to convert to two decimal places
selected_columns =['supply','maxSupply','marketCapUsd','priceUsd','changePercent24Hr','vwap24Hr']
data[selected_columns] = data[selected_columns].applymap(round_to_decimal_places)
data.head()
# Out:
#              id  rank symbol      name        supply    maxSupply  \
# 0       bitcoin     1    BTC   Bitcoin  1.965837e+07   21000000.0
# 1      ethereum     2    ETH  Ethereum  1.200774e+08          0.0
# 2        tether     3   USDT    Tether  1.036182e+11          0.0
# 3  binance-coin     4    BNB       BNB  1.668011e+08  166801148.0
# 4        solana     5    SOL    Solana  4.438849e+08          0.0
#
#    marketCapUsd  volumeUsd24Hr  priceUsd  changePercent24Hr  vwap24Hr  \
# 0  1.355166e+12   1.200640e+10  68935.83              -1.26  69867.25
# 1  4.213456e+11   6.982423e+09   3508.95              -1.89   3564.91
# 2  1.036012e+11   2.807278e+10      1.00              -0.05      1.00
# 3  9.508617e+10   4.770600e+08    570.06              -1.37    575.82
# 4  8.188219e+10   1.416695e+09    184.47              -2.32    186.74
#
#                                             explorer
# 0                           https://blockchain.info/
# 1                              https://etherscan.io/
# 2             https://www.omniexplorer.info/asset/31
# 3  https://etherscan.io/token/0xB8c77482e45F1F44d...
# 4                       https://explorer.solana.com/

# %% [markdown]
# ## Load the data into a Postgress Database

# %%
# Database Credentials
db_username = 'postgres'
db_password = ''
db_host='localhost'
db_port = 5432
db_name = 'Crypto_API_Project'
